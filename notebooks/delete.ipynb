# %%
import pandas as pd
#Read and write to excel

# %%
dataFileUrl = r"../data/coalpublic2012.xls"
data = pd.read_table(dataFileUrl)

# %%
data
# Out:
#                                    <?xml version="1.0"?>
# 0               <?mso-application progid="Excel.Sheet"?>
# 1      <Workbook xmlns="urn:schemas-microsoft-com:off...
# 2       xmlns:o="urn:schemas-microsoft-com:office:off...
# 3       xmlns:x="urn:schemas-microsoft-com:office:excel"
# 4       xmlns:ss="urn:schemas-microsoft-com:office:sp...
# 5          xmlns:html="http://www.w3.org/TR/REC-html40">
# 6       <DocumentProperties xmlns="urn:schemas-micros...
# 7            <LastAuthor>Raghuveer, Tejasvi</LastAuthor>
# 8            <LastSaved>2013-12-16T13:32:57Z</LastSaved>
# 9                               <Version>14.00</Version>
# 10                                 </DocumentProperties>
# 11      <OfficeDocumentSettings xmlns="urn:schemas-mi...
# 12                                           <AllowPNG/>
# 13                             </OfficeDocumentSettings>
# 14      <ExcelWorkbook xmlns="urn:schemas-microsoft-c...
# ...
